# %%
import numpy as np
import pickle
import plotly.graph_objects as go

# %%
## Microwave
ours_file = '/Users/jainajinkya/research/ArticulationModel/results/microwave/ours/nnv1_synArt_20000/test_prediction_data.pkl'
with open(ours_file, 'rb') as f:
    ours = pickle.load(f)

ben_file = '/Users/jainajinkya/research/ArticulationModel/results/microwave/ben/ben_microwave/test_prediction_data.pkl'
with open(ben_file, 'rb') as f:
    ben = pickle.load(f)

## Orientation
fig = go.Figure()
fig.add_trace(go.Histogram(x=ben['ori_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=1))
fig.add_trace(go.Histogram(x=ours['ori_err_mean'], histnorm='percent', name='ScrewNet', bingroup=1))

fig.update_layout(
    title_text='[Microwave] Histogram of mean error in screw axis orientations', # title of plot
    xaxis_title_text='Orientation error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Spatial Distance
fig = go.Figure()
fig.add_trace(go.Histogram(x=ben['dist_err_mean']*100., histnorm='percent', name='Abbatematteo et al.', bingroup=2))
fig.add_trace(go.Histogram(x=ours['dist_err_mean']*100., histnorm='percent', name='ScrewNet', bingroup=2))

fig.update_layout(
    title_text='[Microwave] Histogram of mean error in spatial distance', # title of plot
    xaxis_title_text='Spatial distance error (cm)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Configuration
fig = go.Figure()
fig.add_trace(go.Histogram(x=ben['theta_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=3))
fig.add_trace(go.Histogram(x=ours['theta_err_mean'], histnorm='percent', name='ScrewNet', bingroup=3))

fig.update_layout(
    title_text='[Microwave] Histogram of mean error in configurations', # title of plot
    xaxis_title_text='Configuration error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
#     bargap=0.2, # gap between bars of adjacent location coordinates
#     bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()
# Out:
# <div>
#
#
#             <div id="5fa1a995-18e1-493a-8ede-12b9f0497234" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5fa1a995-18e1-493a-8ede-12b9f0497234")) {
#                     Plotly.newPlot(
#                         '5fa1a995-18e1-493a-8ede-12b9f0497234',
#                         [{"bingroup": "1", "histnorm": "percent", "name": "Abbatematteo et al.", "opacity": 0.75, "type": "histogram", "x": [0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.0014235 ...
# <div>
#
#
#             <div id="5ef99671-3c98-4c9a-9c9d-361f50b7e9bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ef99671-3c98-4c9a-9c9d-361f50b7e9bb")) {
#                     Plotly.newPlot(
#                         '5ef99671-3c98-4c9a-9c9d-361f50b7e9bb',
#                         [{"bingroup": "2", "histnorm": "percent", "name": "Abbatematteo et al.", "opacity": 0.75, "type": "histogram", "x": [2.3847975730895996, 2.879092216491699, 3.589961051940918, 1.819581151008606, 4.025556564331055, 2.5716171264648438, 3.5559699535369873, 2.7184884548187256, 4.366518974304199, 4.301379203796387, 7.568490505218506, 2.9886088371276855, 3.1269571781158447, 3.6534314155578613, 2.690061569213867, 3.4907727241516113, 8.28785514831543, 4.188471794128418, 2.877093553543091, 1.7446086406707764, 3.800144672393799, 5.841942310333252, 2.8224549293518066, 1.9164271354675293, 2.0349204540252686, 6.151180267333984, 4.588159084320068, 3.439195394515991, 5.180306911468506, 2.2731668949127197, 2.2683324813842773, 2.9736030101776123, 2.1912519931793213, 2.834954023361206, 2.5473408699035645, 3.629699230194092, 4.427967548370361, 4.3471808433532715, 3.066579818725586, 2.4413163661956787, 4.032971382141113, 3.6912262439727783, 6.064509391784668, 2.8620996475219727, 2.9678642749786377, 2.5142860412597656, 2.3765337467193604, 3.4788851737976074, 3.0392866134643555, 4.441112041473389, 5.5935235023498535, 2.2682559490203857, 2.286813735961914, 4.257147312164307, 2.5429770946502686, 3.390491008758545, 3.3994693756103516, 2.3889200687408447, 2.3690803050994873, 3.3618669509887695, 2.848879337310791, 2.7966020107269287, 4.645697593688965, 2.460386037826538, 4.861430644989014, 2.880537271499634, 4.588371276855469, 2.374396562576294, 4.2679619789123535, 2.343637466430664, 4.255092144012451, 3.340651035308838, 4.487820148468018, 2.696871280670166, 2.4165563583374023, 1.5814006328582764, 2.2971301078796387, 2.972083806991577, 2.3427350521087646, 6.251984119415283, 4.028197288513184, 3.7186038494110107, 2.3777759075164795, 2.9524078369140625, 3.0898752212524414, 3.3460843563079834, 2.200700044631958, 2.580899477005005, 5.18978214263916, 2.718820095062256, 2.80867600440979, 2.0179858207702637, 3.7419419288635254, 2.8302600383758545, 2.768319606781006, 4.283684730529785, 2.726058006286621, 3.0145599842071533, 2.4270999431610107, 5.102256774902344, 3.9985239505767822, 3.365164279937744, 3.3565263748168945, 4.006137371063232, 1.968023419380188, 5.875523090362549, 2.3802976608276367, 4.276426315307617, 4.555716037750244, 2.4061641693115234, 5.043013572692871, 4.017038345336914, 4.981934547424316, 2.53316330909729, 4.268585681915283, 2.1336324214935303, 5.037895202636719, 1.9738110303878784, 2.483161449432373, 2.607600450515747, 4.654384136199951, 3.3572685718536377, 4.222997665405273, 2.2464141845703125, 3.0785233974456787, 2.4236395359039307, 3.921674966812134, 4.736443042755127, 2.475588321685791, 2.597215175628662, 3.746128797531128, 2.983732223510742, 2.9286720752716064, 2.3728673458099365, 3.5390496253967285, 2.927950859069824, 2.4849376678466797, 2.6788206100463867, 3.8106329441070557, 2.292351245880127, 2.8350088596343994, 2.828618288040161, 3.8243181705474854, 5.44406270980835, 2.6266868114471436, 3.297389268875122, 2.986859083175659, 1.77949857711792, 3.238297939300537, 4.08411169052124, 3.3804070949554443, 6.424449920654297, 2.3175113201141357, 3.373453378677368, 3.0722906589508057, 2.343928098678589, 2.4568326473236084, 2.4186742305755615, 2.722451686859131, 3.010953664779663, 3.3119235038757324, 6.552927017211914, 2.2901084423065186, 3.2148797512054443, 2.731858491897583, 1.9858505725860596, 3.0385942459106445, 2.7247097492218018, 2.0527913570404053, 3.342135190963745, 3.274735450744629, 3.362067461013794, 3.046478033065796, 2.1916322708129883, 1.8793784379959106, 3.3663346767425537, 2.3745779991149902, 3.2226901054382324, 2.6495935916900635, 2.996673583984375, 4.344300746917725, 4.12540864944458, 2.753849983215332, 4.11732816696167, 3.7854671478271484, 2.8834943771362305, 2.5290260314941406, 3.364158868789673, 4.8186798095703125, 1.7736233472824097, 5.276387691497803, 7.696462631225586, 4.715780735015869, 2.9275941848754883, 2.995094060897827, 4.263392925262451, 3.6247446537017822, 2.739755153656006, 1.69314086437 ...
# <div>
#
#
#             <div id="5dc2cd63-e995-47b8-810b-d17545fef46e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5dc2cd63-e995-47b8-810b-d17545fef46e")) {
#                     Plotly.newPlot(
#                         '5dc2cd63-e995-47b8-810b-d17545fef46e',
#                         [{"bingroup": "3", "histnorm": "percent", "name": "Abbatematteo et al.", "opacity": 0.75, "type": "histogram", "x": [0.23559489846229553, 0.2936990559101105, 0.43033039569854736, 0.2581600546836853, 0.6579669117927551, 0.32961517572402954, 0.4945529103279114, 0.4141278564929962, 0.44018983840942383, 0.3675718903541565, 0.36053934693336487, 0.3744826912879944, 0.6486150026321411, 0.3551429212093353, 0.2606247663497925, 0.2663246989250183, 0.5671554803848267, 0.534061849117279, 0.28546082973480225, 0.30250439047813416, 0.5732175707817078, 0.49046674370765686, 0.2715117335319519, 0.24994368851184845, 0.3725634515285492, 0.33821433782577515, 0.3257732689380646, 0.2604459822177887, 0.4889197051525116, 0.17778915166854858, 0.2622266113758087, 0.25086158514022827, 0.6053585410118103, 0.3311920464038849, 0.32986506819725037, 0.5210263729095459, 0.5171316862106323, 0.4782676100730896, 0.31755030155181885, 0.18527862429618835, 0.49986493587493896, 0.5145730972290039, 0.349968820810318, 0.4893850088119507, 0.3265863060951233, 0.5152701139450073, 0.3136674463748932, 0.25743845105171204, 0.3998226523399353, 0.3909454941749573, 0.5708549618721008, 0.4844672679901123, 0.2911487817764282, 0.5087246894836426, 0.33415719866752625, 0.3007201850414276, 0.5094394683837891, 0.28376954793930054, 0.24563448131084442, 0.40525487065315247, 0.3409755527973175, 0.534746527671814, 0.4152832627296448, 0.40773534774780273, 0.5907696485519409, 0.23834814131259918, 0.3415556252002716, 0.553282618522644, 0.38251549005508423, 0.22746442258358002, 0.4937337636947632, 0.5460782647132874, 0.21275365352630615, 0.2816259562969208, 0.4652233123779297, 0.4666852355003357, 0.35491251945495605, 0.2757267951965332, 0.23948855698108673, 0.42102742195129395, 0.28536438941955566, 0.3837510943412781, 0.37184637784957886, 0.3086792826652527, 0.377633661031723, 0.3073115050792694, 0.3633403182029724, 0.2925253212451935, 0.6189125180244446, 0.5866615176200867, 0.5357793569564819, 0.2443256378173828, 0.3044431209564209, 0.4553011953830719, 0.3851761519908905, 0.3336041271686554, 0.2860974073410034, 0.3877964913845062, 0.32283130288124084, 0.3268417716026306, 0.27368661761283875, 0.32688912749290466, 0.24867817759513855, 0.2828061282634735, 0.34548062086105347, 0.25835123658180237, 0.39865997433662415, 0.5347387790679932, 0.27279406785964966, 0.5795888304710388, 0.40736159682273865, 0.33258575201034546, 0.513867974281311, 0.2968488335609436, 0.6703199744224548, 0.3256490230560303, 0.4602615535259247, 0.21915285289287567, 0.2769638001918793, 0.24970674514770508, 0.5200261473655701, 0.6364976167678833, 0.6312329173088074, 0.30594468116760254, 0.31001022458076477, 0.34276363253593445, 0.3419969379901886, 0.589192807674408, 0.4167894721031189, 0.31870269775390625, 0.3059086203575134, 0.4046422243118286, 0.5499744415283203, 0.559598445892334, 0.4217544198036194, 0.29367753863334656, 0.3488529920578003, 0.46298646926879883, 0.44420963525772095, 0.26601189374923706, 0.4069582521915436, 0.20051853358745575, 0.47967544198036194, 0.30689942836761475, 0.3235696852207184, 0.6883999705314636, 0.4229672849178314, 0.2402026653289795, 0.22323179244995117, 0.37945276498794556, 0.352236270904541, 0.42689236998558044, 0.32281413674354553, 0.2017153799533844, 0.29807114601135254, 0.35173556208610535, 0.49829837679862976, 0.43625184893608093, 0.3448253273963928, 0.35619455575942993, 0.2895589768886566, 0.5130468606948853, 0.17825447022914886, 0.42373573780059814, 0.5153517723083496, 0.24181132018566132, 0.3519759476184845, 0.3142765164375305, 0.20806917548179626, 0.46468305587768555, 0.24541723728179932, 0.33838963508605957, 0.35334697365760803, 0.3298744857311249, 0.28223752975463867, 0.3660339415073395, 0.33552616834640503, 0.2466830015182495, 0.3874868154525757, 0.24994473159313202, 0.26286405324935913, 0.30495041608810425, 0.5078899264335632, 0.31128931045532227, 0.36796727776527405, 0.3151096999645233, 0.44726628065109253, 0.19395987689495087, 0.467925488948822, 0.2210470 ...

# %%
## Drawer
ours_file = '/Users/jainajinkya/research/ArticulationModel/results/drawer/ours/nnv1_synArt_20000/test_prediction_data.pkl'
with open(ours_file, 'rb') as f:
    ours = pickle.load(f)

ben_file = '/Users/jainajinkya/research/ArticulationModel/results/drawer/ben/ben_drawer/test_prediction_data.pkl'
with open(ben_file, 'rb') as f:
    ben = pickle.load(f)

## Orientation
fig = go.Figure()
fig.add_trace(go.Histogram(x=ben['ori_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=1))
fig.add_trace(go.Histogram(x=ours['ori_err_mean'], histnorm='percent', name='ScrewNet', bingroup=1))

fig.update_layout(
    title_text='[Drawer] Histogram of mean error in screw axis orientations', # title of plot
    xaxis_title_text='Orientation error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Spatial Distance
fig = go.Figure()
fig.add_trace(go.Histogram(x=ben['dist_err_mean']*100., histnorm='percent', name='Abbatematteo et al.', bingroup=2))
fig.add_trace(go.Histogram(x=ours['dist_err_mean']*100., histnorm='percent', name='ScrewNet', bingroup=2))

fig.update_layout(
    title_text='[Drawer] Histogram of mean error in spatial distance', # title of plot
    xaxis_title_text='Spatial distance error (cm)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Configuration
fig = go.Figure()
fig.add_trace(go.Histogram(x=ben['theta_err_mean']*100., histnorm='percent', name='Abbatematteo et al.', bingroup=3))
fig.add_trace(go.Histogram(x=ours['ori_d_mean']*100., histnorm='percent', name='ScrewNet', bingroup=3))

fig.update_layout(
    title_text='[Drawer] Histogram of mean error in configurations', # title of plot
    xaxis_title_text='Configuration error (cm)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
#     bargap=0.2, # gap between bars of adjacent location coordinates
#     bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()
# Out:
# <div>
#
#
#             <div id="2404e648-6f22-486d-a5c2-dfcd5c3f1743" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2404e648-6f22-486d-a5c2-dfcd5c3f1743")) {
#                     Plotly.newPlot(
#                         '2404e648-6f22-486d-a5c2-dfcd5c3f1743',
#                         [{"bingroup": "1", "histnorm": "percent", "name": "Abbatematteo et al.", "opacity": 0.75, "type": "histogram", "x": [0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.001423572306521237, 0.0014235 ...
# <div>
#
#
#             <div id="0809ffbb-9fad-41fd-a094-ad219acf6bb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0809ffbb-9fad-41fd-a094-ad219acf6bb4")) {
#                     Plotly.newPlot(
#                         '0809ffbb-9fad-41fd-a094-ad219acf6bb4',
#                         [{"bingroup": "2", "histnorm": "percent", "name": "Abbatematteo et al.", "opacity": 0.75, "type": "histogram", "x": [3.8800227642059326, 4.829587936401367, 2.668964385986328, 3.061185598373413, 5.550463676452637, 5.377374172210693, 4.514472961425781, 3.524661064147949, 3.2553248405456543, 5.565899848937988, 2.341643810272217, 4.037680625915527, 3.9161741733551025, 2.9543538093566895, 4.769000053405762, 3.4445643424987793, 4.0650553703308105, 3.299079179763794, 4.865976333618164, 4.227845191955566, 6.502075672149658, 3.6663553714752197, 4.413248062133789, 5.279201984405518, 12.615550994873047, 3.8934335708618164, 6.000185489654541, 5.317330837249756, 6.116664409637451, 3.0832507610321045, 3.1825172901153564, 2.49678373336792, 2.7834973335266113, 2.0330564975738525, 5.061226844787598, 3.4620885848999023, 5.707777500152588, 2.304656505584717, 9.465717315673828, 2.8895297050476074, 3.3202593326568604, 4.105761528015137, 3.854635000228882, 6.87276029586792, 2.5566017627716064, 4.174647331237793, 3.19966459274292, 9.844059944152832, 2.8379504680633545, 4.806900501251221, 4.455641269683838, 3.4327220916748047, 5.2473626136779785, 3.1751816272735596, 4.419647216796875, 4.480842113494873, 2.034858226776123, 4.150622367858887, 3.6976144313812256, 5.104247570037842, 4.144754409790039, 4.621296405792236, 3.101994276046753, 4.228442192077637, 5.3317084312438965, 2.2922093868255615, 4.914835453033447, 3.48657488822937, 5.283248424530029, 4.466833114624023, 2.8833999633789062, 3.684756278991699, 4.32330322265625, 5.138298988342285, 2.5750784873962402, 2.831549882888794, 3.4419326782226562, 5.1366071701049805, 3.057147264480591, 5.206728935241699, 4.852123737335205, 2.612266778945923, 2.9332361221313477, 4.211266994476318, 4.296419620513916, 3.373000144958496, 4.769074440002441, 4.725704193115234, 4.617368698120117, 3.123685359954834, 2.2699508666992188, 5.639488220214844, 3.140002489089966, 3.686476469039917, 4.238924980163574, 4.109361171722412, 3.77052903175354, 3.8060479164123535, 2.968660593032837, 2.7253477573394775, 3.2746381759643555, 4.143436431884766, 3.375467300415039, 3.8506228923797607, 4.04538106918335, 3.6237354278564453, 3.6218721866607666, 4.72325325012207, 3.3932182788848877, 5.592031955718994, 6.470045566558838, 2.118860960006714, 3.5307023525238037, 3.9493088722229004, 4.0390706062316895, 3.4389235973358154, 3.797159433364868, 3.2585608959198, 3.593027114868164, 3.9191160202026367, 3.653716564178467, 3.2757468223571777, 2.5265254974365234, 4.845613956451416, 5.104223251342773, 5.163776397705078, 2.908914804458618, 2.7082467079162598, 2.929426670074463, 7.355155944824219, 2.802534580230713, 3.564281463623047, 3.96378231048584, 4.016266345977783, 3.0964717864990234, 4.504493236541748, 2.188582420349121, 3.2368392944335938, 3.806196451187134, 3.9440929889678955, 2.5849459171295166, 3.871255397796631, 3.8899145126342773, 3.477558135986328, 4.821923732757568, 2.8409652709960938, 3.0543577671051025, 3.88757061958313, 2.914116621017456, 2.6643917560577393, 4.41998291015625, 5.737321853637695, 3.177466869354248, 4.165234088897705, 3.7198424339294434, 2.5765058994293213, 5.5910444259643555, 3.6613974571228027, 2.845618724822998, 3.051124095916748, 4.102633476257324, 3.4197230339050293, 3.690014123916626, 4.321159362792969, 5.320080280303955, 5.497408866882324, 2.352234363555908, 3.2343597412109375, 4.383571624755859, 11.031896591186523, 5.47448205947876, 3.5283942222595215, 3.5138607025146484, 3.931948661804199, 3.0928754806518555, 3.311314105987549, 3.990520477294922, 5.153335094451904, 5.989973068237305, 3.71132493019104, 9.82594108581543, 2.5635433197021484, 4.707701683044434, 2.4539976119995117, 3.645512104034424, 4.743220806121826, 4.4643073081970215, 6.830243110656738, 2.5242762565612793, 2.999288558959961, 4.19050407409668, 2.7811338901519775, 3.3131375312805176, 3.4540817737579346, 4.247483730316162, 3.149946451187134, 3.171765089035034, 3.41650390625, 4.062671184539795, 3.2065696716308594, 2.0447099 ...
# <div>
#
#
#             <div id="cb50a450-0c60-4351-b564-36035e0a6a59" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cb50a450-0c60-4351-b564-36035e0a6a59")) {
#                     Plotly.newPlot(
#                         'cb50a450-0c60-4351-b564-36035e0a6a59',
#                         [{"bingroup": "3", "histnorm": "percent", "name": "Abbatematteo et al.", "opacity": 0.75, "type": "histogram", "x": [7.618838310241699, 8.28274917602539, 8.695218086242676, 5.843122959136963, 4.436749458312988, 7.318869113922119, 3.231048583984375, 6.346607208251953, 4.439352989196777, 4.143388748168945, 5.1533894538879395, 12.717370986938477, 6.121121406555176, 3.9858832359313965, 7.725658893585205, 6.668481349945068, 5.046309471130371, 8.510482788085938, 7.545966625213623, 3.0115764141082764, 7.536690711975098, 7.673553466796875, 6.902154445648193, 7.0623779296875, 6.515374660491943, 7.026272296905518, 10.008195877075195, 5.6852192878723145, 6.535620212554932, 9.604426383972168, 8.393917083740234, 9.520669937133789, 7.804874420166016, 7.083416938781738, 7.546083450317383, 8.99004077911377, 4.154337406158447, 10.840581893920898, 4.643665790557861, 8.31898307800293, 3.905535936355591, 7.544682025909424, 5.773001194000244, 6.400252819061279, 6.30703067779541, 4.8832926750183105, 4.985762596130371, 7.290041446685791, 9.512787818908691, 7.616446018218994, 5.476648807525635, 7.406984329223633, 6.617769718170166, 6.4823479652404785, 6.333011627197266, 7.432068347930908, 10.362221717834473, 5.203453063964844, 7.291711807250977, 6.550411701202393, 4.607892036437988, 5.965613842010498, 13.020059585571289, 8.05569839477539, 7.817461967468262, 10.618576049804688, 3.922485589981079, 9.751086235046387, 8.321112632751465, 9.881718635559082, 9.634843826293945, 4.559667587280273, 7.449709415435791, 8.772340774536133, 9.810995101928711, 7.569255828857422, 4.693112850189209, 6.724231719970703, 7.3909173011779785, 3.5960288047790527, 7.026429653167725, 5.651854515075684, 8.353517532348633, 8.316349029541016, 4.5977396965026855, 7.123429298400879, 7.909937858581543, 4.235487937927246, 8.942646980285645, 9.021809577941895, 9.804459571838379, 5.735539436340332, 6.467741966247559, 7.625380039215088, 5.669499397277832, 11.845924377441406, 8.122276306152344, 7.601504802703857, 8.656513214111328, 10.204017639160156, 6.863714694976807, 3.9777026176452637, 6.44221305847168, 5.556833267211914, 9.104369163513184, 9.087053298950195, 6.222784996032715, 5.325432300567627, 7.032401084899902, 6.739710330963135, 6.105125904083252, 5.813014507293701, 4.656863212585449, 5.359898567199707, 7.209487438201904, 10.956719398498535, 7.342312335968018, 9.938131332397461, 7.39825439453125, 1.8957180976867676, 11.199677467346191, 5.456387042999268, 6.389930248260498, 10.736692428588867, 8.934527397155762, 7.351332187652588, 3.977512836456299, 7.414816856384277, 9.113099098205566, 6.726532936096191, 11.453187942504883, 9.210346221923828, 7.657192707061768, 5.237290859222412, 6.671191215515137, 7.958863735198975, 9.578474998474121, 11.170760154724121, 11.601204872131348, 8.265302658081055, 6.715599536895752, 7.024440288543701, 5.070554256439209, 6.821608543395996, 8.434556007385254, 10.524441719055176, 8.223188400268555, 3.6512515544891357, 10.323236465454102, 4.261751651763916, 7.016379356384277, 5.884277820587158, 7.242691516876221, 14.916716575622559, 6.265239238739014, 8.309074401855469, 6.352516174316406, 11.337137222290039, 9.726652145385742, 6.800626754760742, 5.5221452713012695, 12.342668533325195, 8.82506275177002, 11.283679008483887, 6.358826160430908, 4.569896697998047, 10.175202369689941, 3.922600030899048, 3.4677271842956543, 4.975124359130859, 6.522268295288086, 12.949045181274414, 9.14274787902832, 9.057048797607422, 6.64056921005249, 7.519246578216553, 14.155828475952148, 5.344377040863037, 5.783318042755127, 8.003802299499512, 11.736865043640137, 6.6718621253967285, 5.141236305236816, 9.257781028747559, 8.271862983703613, 5.606925964355469, 11.226603507995605, 8.423354148864746, 9.993077278137207, 4.271149158477783, 12.244776725769043, 5.706546783447266, 5.267761707305908, 10.85524845123291, 5.241490364074707, 10.277749061584473, 5.855324745178223, 3.9296751022338867, 6.857217788696289, 6.606802940368652, 5.253176212310791, 5.6138777 ...

# %%
## Toaster
ours_file = '/Users/jainajinkya/research/ArticulationModel/results/toaster/ours/nnv1_synArt_20000/test_prediction_data.pkl'
with open(ours_file, 'rb') as f:
    ours = pickle.load(f)

ben_toast_f = '/Users/jainajinkya/research/ArticulationModel/results/toaster/ben/ben_toaster/test_prediction_data.pkl'
with open(ben_toast_f, 'rb') as f:
    ben_toast = pickle.load(f)

## Orientation
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['ori_err_mean'], histnorm='percent', name='ScrewNet', bingroup=1))
fig.add_trace(go.Histogram(x=ben_toast['ori_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=1))

fig.update_layout(
    title_text='[Toaster] Histogram of mean error in screw axis orientations', # title of plot
    xaxis_title_text='Orientation error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Spatial Distance
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['dist_err_mean']*100., histnorm='percent', name='ScrewNet', bingroup=2))
fig.add_trace(go.Histogram(x=ben_toast['dist_err_mean']*100., histnorm='percent', name='Abbatematteo et al.', bingroup=2))

fig.update_layout(
    title_text='[Toaster] Histogram of mean error in spatial distance', # title of plot
    xaxis_title_text='Spatial distance error (cm)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Configuration
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['theta_err_mean'], histnorm='percent', name='ScrewNet', bingroup=3))
fig.add_trace(go.Histogram(x=ben_toast['theta_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=3))

fig.update_layout(
    title_text='[Toaster] Histogram of mean error in configurations', # title of plot
    xaxis_title_text='Configuration error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
#     bargap=0.2, # gap between bars of adjacent location coordinates
#     bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

# %%
## Cabinet
ours_file = '/Users/jainajinkya/research/ArticulationModel/results/cabinet/ours/nnv1_synArt_20000/test_prediction_data.pkl'
with open(ours_file, 'rb') as f:
    ours = pickle.load(f)

# ben_toast_f = '/Users/jainajinkya/research/ArticulationModel/results/cabinet/ben/ben_toaster/test_prediction_data.pkl'
# with open(ben_toast_f, 'rb') as f:
#     ben_toast = pickle.load(f)

## Orientation
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['ori_err_mean'], histnorm='percent', name='ScrewNet', bingroup=1))
# fig.add_trace(go.Histogram(x=ben_toast['ori_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=1))

fig.update_layout(
    title_text='[Cabinet] Histogram of mean error in screw axis orientations', # title of plot
    xaxis_title_text='Orientation error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Spatial Distance
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['dist_err_mean']*100., histnorm='percent', name='ScrewNet', bingroup=2))
# fig1.add_trace(go.Histogram(x=ben_toast['dist_err_mean']*100., histnorm='percent', name='Abbatematteo et al.', bingroup=2))

fig.update_layout(
    title_text='[Cabinet] Histogram of mean error in spatial distance', # title of plot
    xaxis_title_text='Spatial distance error (cm)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Configuration
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['theta_err_mean'], histnorm='percent', name='ScrewNet', bingroup=3))
# fig.add_trace(go.Histogram(x=ben_toast['theta_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=3))

fig.update_layout(
    title_text='[Cabinet] Histogram of mean error in configurations', # title of plot
    xaxis_title_text='Configuration error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
#     bargap=0.2, # gap between bars of adjacent location coordinates
#     bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

# %%
## Sapien Microwave
ours_file = '/Users/jainajinkya/research/ArticulationModel/results/mixed/ours/safekeeping/sap_mw_10000_nnv1_new/test_prediction_data.pkl'
with open(ours_file, 'rb') as f:
    ours = pickle.load(f)

ben_toast_f = '/Users/jainajinkya/research/ArticulationModel/results/ben/sap_mw_1/test_prediction_data.pkl'
with open(ben_toast_f, 'rb') as f:
    ben_toast = pickle.load(f)

## Orientation
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['ori_err_mean'], histnorm='percent', name='ScrewNet', bingroup=1))
fig.add_trace(go.Histogram(x=ben_toast['ori_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=1))

fig.update_layout(
    title_text='[Sapien: Microwave] Histogram of mean error in screw axis orientations', # title of plot
    xaxis_title_text='Orientation error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)

fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Spatial Distance
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['dist_err_mean']*100., histnorm='percent', name='ScrewNet', bingroup=2))
fig.add_trace(go.Histogram(x=ben_toast['dist_err_mean']*100., histnorm='percent', name='Abbatematteo et al.', bingroup=2))

fig.update_layout(
    title_text='[Sapien: Microwave] Histogram of mean error in spatial distance', # title of plot
    xaxis_title_text='Spatial distance error (cm)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()

## Configuration
fig = go.Figure()
fig.add_trace(go.Histogram(x=ours['theta_err_mean'], histnorm='percent', name='ScrewNet', bingroup=3))
fig.add_trace(go.Histogram(x=ben_toast['theta_err_mean'], histnorm='percent', name='Abbatematteo et al.', bingroup=3))

fig.update_layout(
    title_text='[Sapien: Microwave] Histogram of mean error in configurations', # title of plot
    xaxis_title_text='Configuration error (radians)', # xaxis label
    yaxis_title_text='Percentage of test objects', # yaxis label
#     bargap=0.2, # gap between bars of adjacent location coordinates
#     bargroupgap=0.1, # gap between bars of the same location coordinates
    barmode='overlay'
)

# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.update_layout(legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()
